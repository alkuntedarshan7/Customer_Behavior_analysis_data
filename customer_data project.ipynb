# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\ASUS\\OneDrive\\Desktop\\jupyter notebook\\customer_shopping_behavior.csv")

# %%
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
df.describe(include='all')
# Out:
#         Customer ID          Age Gender Item Purchased  Category  \
# count   3900.000000  3900.000000   3900           3900      3900
# unique          NaN          NaN      2             25         4
# top             NaN          NaN   Male         Blouse  Clothing
# freq            NaN          NaN   2652            171      1737
# mean    1950.500000    44.068462    NaN            NaN       NaN
# std     1125.977353    15.207589    NaN            NaN       NaN
# min        1.000000    18.000000    NaN            NaN       NaN
# 25%      975.750000    31.000000    NaN            NaN       NaN
# 50%     1950.500000    44.000000    NaN            NaN       NaN
# 75%     2925.250000    57.000000    NaN            NaN       NaN
# max     3900.000000    70.000000    NaN            NaN       NaN
#
#         Purchase Amount (USD) Location  Size  Color  Season  Review Rating  \
# count             3900.000000     3900  3900   3900    3900    3863.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   str
#  3   Item Purchased          3900 non-null   str
#  4   Category                3900 non-null   str
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   str
#  7   Size                    3900 non-null   str
#  8   Color                   3900 non-null   str
#  9   Season                  3900 non-null   str
#  10  Review Rating           3863 non-null   float64
#  11  Subscription Status     3900 non-null   str
#  12  Shipping Type           3900 non-null   str
#  13  Discount Applied        3900 non-null   str
#  14  Promo Code Used         3900 non-null   str
# ...

# %%
df.isnull().sum()
# Out:
# Customer ID                0
# Age                        0
# Gender                     0
# Item Purchased             0
# Category                   0
# Purchase Amount (USD)      0
# Location                   0
# Size                       0
# Color                      0
# Season                     0
# Review Rating             37
# Subscription Status        0
# Shipping Type              0
# Discount Applied           0
# Promo Code Used            0
# Previous Purchases         0
# Payment Method             0
# Frequency of Purchases     0
# dtype: int64

# %%
# meadian within each category
df['Review Rating'] = df.groupby('Category')['Review Rating'].transform(lambda x: x.fillna(x.median()))

# %%
df.isnull().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Promo Code Used           0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# dtype: int64

# %%
df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace(' ', '_')
df.rename(columns={'purchase_amount_(usd)': 'purchase_amount'}, inplace=True)

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'promo_code_used', 'previous_purchases',
#        'payment_method', 'frequency_of_purchases', 'age_group'],
#       dtype='str')

# %%
# create a new column for age group
labels = ['young', 'adult', 'middle-aged', 'senior']
df['age_group'] = pd.qcut(df['age'], q=4, labels=labels)

# %%
df[['age', 'age_group']].head(7)
# Out:
#    age    age_group
# 0   55  middle-aged
# 1   19        young
# 2   50  middle-aged
# 3   21        young
# 4   45  middle-aged
# 5   46  middle-aged
# 6   63       senior

# %%
# purchase frequency 
frequency_mapping = {
    "Fortnightly": 14,
    "Weekly": 7,
    "Monthly": 30,
    "Bi-weekly": 14,
    "Quarterly": 90,
    "Every 3 Months": 90,
    'Annually': 365
}
df['purchase_frequency_days'] = df['frequency_of_purchases'].map(frequency_mapping)
print(df)
# Out:
#       customer_id  age  gender item_purchased     category  purchase_amount  \
# 0               1   55    Male         Blouse     Clothing               53
# 1               2   19    Male        Sweater     Clothing               64
# 2               3   50    Male          Jeans     Clothing               73
# 3               4   21    Male        Sandals     Footwear               90
# 4               5   45    Male         Blouse     Clothing               49
# ...           ...  ...     ...            ...          ...              ...
# 3895         3896   40  Female         Hoodie     Clothing               28
# 3896         3897   52  Female       Backpack  Accessories               49
# 3897         3898   46  Female           Belt  Accessories               33
# 3898         3899   44  Female          Shoes     Footwear               77
# 3899         3900   52  Female        Handbag  Accessories               81
#
# ...

# %%
df[['purchase_frequency_days','frequency_of_purchases']].head(7)
# Out:
#    purchase_frequency_days frequency_of_purchases
# 0                     14.0            Fortnightly
# 1                     14.0            Fortnightly
# 2                      7.0                 Weekly
# 3                      7.0                 Weekly
# 4                    365.0               Annually
# 5                      7.0                 Weekly
# 6                     90.0              Quarterly

# %%
(df[ 'discount_applied'] == df['promo_code_used']).all()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\ASUS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'promo_code_used'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[100], line 1
# ...

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'previous_purchases', 'payment_method',
#        'frequency_of_purchases', 'age_group', 'purchase_frequency_days'],
#       dtype='str')

# %%
# %pip install pandas sqlalchemy pymysql
# Out:
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.1 MB ? eta -:--:--
#    -------------- ------------------------- 0.8/2.1 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------  2.1/2.1 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 4.4 MB/s  0:00:00
# ...
#
#    ------------- -------------------------- 1/3 [greenlet]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
#    -------------------------- ------------- 2/3 [sqlalchemy]
# ...

# %%
import os
import getpass
import pandas as pd
from sqlalchemy import create_engine

# %%
DB_USER = input("DB user: ")
DB_HOST = input("DB host (e.g. 127.0.0.1): ")
DB_NAME = "customer_behaviour"
DB_PASS = getpass.getpass("DB password (hidden): ")




# Create the connection string

# %%
from urllib.parse import quote_plus
pwd = quote_plus(DB_PASS)
engine = create_engine(f"mysql+pymysql://{DB_USER}:{pwd}@{DB_HOST}:3306/{DB_NAME}")

# %%
from urllib.parse import quote_plus
engine = create_engine(f"mysql+pymysql://{DB_USER}:{quote_plus(DB_PASS)}@{DB_HOST}:3306/{DB_NAME}")

# %%
engine = create_engine(f"mysql+pymysql://{DB_USER}:{DB_PASS}@{DB_HOST}:3306/{DB_NAME}")

# %%
import getpass
from urllib.parse import quote_plus
from sqlalchemy import create_engine

DB_USER = input("DB user: ")
DB_HOST = input("DB host: ")
DB_NAME = "customer_behaviour"
DB_PASS = getpass.getpass("DB password (hidden): ")

engine = create_engine(
    f"mysql+pymysql://{DB_USER}:{quote_plus(DB_PASS)}@{DB_HOST}:3306/{DB_NAME}"
)

# %%
import os
os.environ["DB_PASS"] = "Darshan@1623"
# then read it
DB_PASS = os.environ.get("DB_PASS")

# %%
import getpass
DB_USER = input("root@localhost: ")
DB_HOST = input("DB host (e.g. 127.0.0.1 or DRACAYRUS): ")
DB_NAME = "customer_behaviour"
DB_PASS = getpass.getpass("DB password (Darshan@1623): ")

# %%
from urllib.parse import quote_plus
from sqlalchemy import create_engine

engine = create_engine(
    f"mysql+pymysql://{"root@localhost"}:{quote_plus("Darshan@1623")}@{'DRACAYRUS'}:3306/{'customer_behaviour'}"
)

# %%
engine = create_engine(
    "mysql+pymysql://analysis_user:Darshan1623@127.0.0.1:3306/customer_behaviour"
)

# %%
import pandas as pd

df = pd.read_csv("C:\\Users\\ASUS\\OneDrive\\Desktop\\jupyter notebook\\customer_shopping_behavior.csv")

df.rename(columns={
    "Customer ID": "customer_id",
    "Age": "age",
    "Gender": "gender",
    "Item Purchased": "item_purchased",
    "Category": "category",
    "Purchase Amount (USD)": "purchase_amount",
    "Location": "location",
    "Size": "size",
    "Color": "color",
    "Season": "season",
    "Review Rating": "review_rating",
    "Subscription Status": "subscription_status",
    "Shipping Type": "shipping_type",
    "Discount Applied": "discount_applied",
    "Previous Purchases": "previous_purchases",
    "Payment Method": "payment_method",
    "Frequency of Purchases": "frequency_of_purchases"
}, inplace=True)


# Add your new derived columns if not already present
df["age_group"] = pd.cut(df["age"], bins=[0,18,35,50,100],
                         labels=["Teen","Young Adult","Adult","Senior"])
df["purchase_frequency_days"] = df["frequency_of_purchases"].map({
    "Weekly": 7,
    "Fortnightly": 14,
    "Quarterly": 90,
    "Annually": 365
})

# %%
from sqlalchemy import create_engine

engine = create_engine(
    "mysql+pymysql://analysis_user:Darshan1623@127.0.0.1:3306/customer_behaviour"
)

# %%
df.to_sql("customer_data", con=engine, if_exists="replace", index=False)
print("Table updated successfully with new schema and data!")
# Out:
# Table updated successfully with new schema and data!

# %%
with engine.connect() as conn:
    result = conn.execute(text("SELECT COUNT(*) FROM customer_data"))
    print("Row count:", result.scalar())
# Out:
# Row count: 3900

# %%
with engine.connect() as conn:
    conn.execute(text("ALTER TABLE customer_data DROP COLUMN `Promo Code Used`"))
    print("Column 'Promo Code Used' deleted successfully!")
# Out:
# Column 'Promo Code Used' deleted successfully!

# %%
with engine.connect() as conn:
    result = conn.execute(text("SHOW COLUMNS FROM customer_data"))
    for row in result:
        print(row)
# Out:
# ('customer_id', 'bigint', 'YES', '', None, '')
# ('age', 'bigint', 'YES', '', None, '')
# ('gender', 'text', 'YES', '', None, '')
# ('item_purchased', 'text', 'YES', '', None, '')
# ('category', 'text', 'YES', '', None, '')
# ('purchase_amount', 'bigint', 'YES', '', None, '')
# ('location', 'text', 'YES', '', None, '')
# ('size', 'text', 'YES', '', None, '')
# ('color', 'text', 'YES', '', None, '')
# ('season', 'text', 'YES', '', None, '')
# ('review_rating', 'double', 'YES', '', None, '')
# ('subscription_status', 'text', 'YES', '', None, '')
# ('shipping_type', 'text', 'YES', '', None, '')
# ('discount_applied', 'text', 'YES', '', None, '')
# ('Promo Code Used', 'text', 'YES', '', None, '')
# ('previous_purchases', 'bigint', 'YES', '', None, '')
# ('payment_method', 'text', 'YES', '', None, '')
# ('frequency_of_purchases', 'text', 'YES', '', None, '')
# ('age_group', 'text', 'YES', '', None, '')
# ('purchase_frequency_days', 'double', 'YES', '', None, '')

# %%
df.to_sql("customer_data", con=engine, if_exists="replace", index=False)
print("Table replaced with updated CSV data!")
# Out:
# Table replaced with updated CSV data!

# %%
df.to_sql("customer_data_", con=engine, if_exists="append", index=False)
print("Updated rows appended to table!")
# Out:
# Updated rows appended to table!

# %%
from sqlalchemy import create_engine
import pandas as pd

# Connection string using analysis_user
engine = create_engine(
    "mysql+pymysql://analysis_user:Darshan1623@127.0.0.1:3306/customer_behaviour"
)

# Test query
df = pd.read_sql("SHOW TABLES;", engine)
print(df)
# Out:
#   Tables_in_customer_behaviour
# 0      customer_behaviour_data
# 1                customer_data
# 2               customer_data_
# 3   customer_shopping_behavior

# %%
from sqlalchemy import text

with engine.connect() as conn:
    result = conn.execute(text("SELECT COUNT(*) FROM customer_data"))
    print("Row count:", result.scalar())
# Out:
# Row count: 3900

# %%
with engine.connect() as conn:
    result = conn.execute(text("SHOW TABLES"))
    print(result.fetchall())
# Out:
# [('customer_behaviour_data',), ('customer_data',), ('customer_data_',), ('customer_shopping_behavior',)]

# %%
from sqlalchemy import create_engine

engine = create_engine(
    "mysql+pymysql://analysis_user:Darshan1623@127.0.0.1:3306/customer_behaviour"
)

# %%
import mysql.connector
from mysql.connector import Error

config = {
    "user": "temp_bi",
    "password": "TempBI!234",
    "host": "127.0.0.1",
    "port": 3306,
    "database": "customer_behaviour",
    "connection_timeout": 5
}

try:
    conn = mysql.connector.connect(**config)
    print("Connected:", conn.is_connected())
    cur = conn.cursor()
    cur.execute("SELECT COUNT(*) FROM information_schema.tables WHERE table_schema='customer_behaviour';")
    print("Tables in customer_behaviour:", cur.fetchone()[0])
    cur.close()
    conn.close()
except Error as e:
    print("Connection error:", e)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[141], line 1
# ----> 1 import mysql.connector
#       2 from mysql.connector import Error
#       4 config = {
#       5     "user": "temp_bi",
#       6     "password": "TempBI!234",
#    (...)     10     "connection_timeout": 5
#      11 }
#
# ModuleNotFoundError: No module named 'mysql'

# %%
# Run this cell after restarting the kernel
import mysql.connector
from mysql.connector import Error

cfg = {
    "user": "temp_bi",
    "password": "TempBI!234",
    "host": "127.0.0.1",
    "port": 3306,
    "database": "customer_behaviour",
    "connection_timeout": 5
}

try:
    conn = mysql.connector.connect(**cfg)
    print("Connected:", conn.is_connected())
    cur = conn.cursor()
    cur.execute("SELECT COUNT(*) FROM information_schema.tables WHERE table_schema='customer_behaviour';")
    print("Tables in customer_behaviour:", cur.fetchone()[0])
    cur.close()
    conn.close()
except Error as e:
    print("Connection error:", e)
# Out:
# Connected: True
# Tables in customer_behaviour: 4

# %%
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine("mysql+pymysql://temp_bi:TempBI%21234@127.0.0.1:3306/customer_behaviour")
with engine.connect() as conn:
    df = pd.read_sql_query("SELECT TABLE_NAME FROM INFORMATION_SCHEMA.TABLES WHERE TABLE_SCHEMA='customer_behaviour' LIMIT 5;", conn)
print(df)
# Out:
#                    TABLE_NAME
# 0     customer_behaviour_data
# 1               customer_data
# 2              customer_data_
# 3  customer_shopping_behavior

# %%
import mysql.connector
cfg = {"user":"temp_bi","password":"TempBI!234","host":"127.0.0.1","port":3306,"database":"customer_behaviour"}
conn = mysql.connector.connect(**cfg)
cur = conn.cursor()
cur.execute("SHOW TABLES LIKE 'customer_data';")
print("tables:", cur.fetchall())
cur.execute("SELECT COUNT(*) FROM customer_data;")
print("rows:", cur.fetchone()[0])
cur.close(); conn.close()
# Out:
# tables: [('customer_data',)]
# rows: 3900

# %%
from sqlalchemy import create_engine, text

engine = create_engine("mysql+pymysql://temp_bi:TempBI%21234@127.0.0.1:3306/customer_behaviour")
with engine.connect() as conn:
    # show tables
    result = conn.execute(text("SHOW TABLES LIKE 'customer_data';"))
    print("tables:", result.fetchall())

    # row count
    result = conn.execute(text("SELECT COUNT(*) FROM customer_data;"))
    print("rows:", result.scalar())

    # columns
    result = conn.execute(text("SHOW COLUMNS FROM customer_data;"))
    print("columns:", [row[0] for row in result.fetchall()])
# Out:
# tables: [('customer_data',)]
# rows: 3900
# columns: ['customer_id', 'age', 'gender', 'item_purchased', 'category', 'purchase_amount', 'location', 'size', 'color', 'season', 'review_rating', 'subscription_status', 'shipping_type', 'discount_applied', 'previous_purchases', 'payment_method', 'frequency_of_purchases', 'age_group', 'purchase_frequency_days']

# %%
import mysql.connector
cfg = {"user":"temp_bi","password":"TempBI!234","host":"127.0.0.1","port":3306,"database":"customer_behaviour"}
with mysql.connector.connect(**cfg) as conn:
    cur = conn.cursor()
    cur.execute("SHOW TABLES LIKE 'customer_data';")
    print("tables:", cur.fetchall())
    cur.execute("SELECT COUNT(*) FROM customer_data;")
    print("rows:", cur.fetchone()[0])
    cur.execute("SHOW COLUMNS FROM customer_data;")
    print("columns:", [r[0] for r in cur.fetchall()])
    cur.close()
# Out:
# tables: [('customer_data',)]
# rows: 3900
# columns: ['customer_id', 'age', 'gender', 'item_purchased', 'category', 'purchase_amount', 'location', 'size', 'color', 'season', 'review_rating', 'subscription_status', 'shipping_type', 'discount_applied', 'previous_purchases', 'payment_method', 'frequency_of_purchases', 'age_group', 'purchase_frequency_days']
